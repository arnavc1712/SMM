# %%
# !pip install tweepy
# !pip install networkx
# Out:
# Requirement already satisfied: tweepy in /usr/local/lib/python2.7/site-packages (3.8.0)
# Requirement already satisfied: requests>=2.11.1 in /usr/local/lib/python2.7/site-packages (from tweepy) (2.19.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python2.7/site-packages (from tweepy) (1.11.0)
# Requirement already satisfied: PySocks>=1.5.7 in /usr/local/lib/python2.7/site-packages (from tweepy) (1.7.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python2.7/site-packages (from tweepy) (1.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python2.7/site-packages (from requests>=2.11.1->tweepy) (2018.1.18)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python2.7/site-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in /usr/local/lib/python2.7/site-packages (from requests>=2.11.1->tweepy) (1.23)
# Requirement already satisfied: idna<2.8,>=2.5 in /usr/local/lib/python2.7/site-packages (from requests>=2.11.1->tweepy) (2.7)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python2.7/site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.0)
# Collecting networkx
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python2.7/site-packages (from networkx) (4.3.0)
# Installing collected packages: networkx
# Successfully installed networkx-2.2

# %%
import tweepy
from pprint import pprint
import json
import networkx as nx
import time
import matplotlib.pyplot as plt

# %%
consumer_key = "a3viE9zsnehj18AS37qvyGtls"
consumer_secret = "L07cOhvQuNt4W20R3AeSFuXmCiVdcyLfiFbeYlV7gq4m97unz7"
access_token = "724311312-Ynce64galfx3EBK3BMKirvkMhHtYxmImeEIbd0nG"
access_token_secret = "PVOdxleUDq9sfviPACiLydvTMAO8Esjf3PK37OlEk80mA"

# %%
# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information

# %%
api = tweepy.API(auth) 
graph=nx.DiGraph()

# %%
def limit_handler(cursor):
    while True:
        try:
            yield cursor.next()
        except tweepy.RateLimitError:
            time.sleep(2 * 60)

# %%
print("Loading followers of me into a List")
followers = []

for follower in limit_handler(tweepy.Cursor(api.followers).items()):
    followers.append(follower)
# Out:
# Loading followers of me into a List

# %%
pprint(followers[0])
# Out:
# User(follow_request_sent=False, has_extended_profile=False, profile_use_background_image=True, profile_sidebar_fill_color=u'DDEEF6', live_following=False, time_zone=None, id=1029621764719083520, description=u'https://t.co/yVtFx9XoeD is the largest online community for programmers to learn, share their knowledge and build their careers.', _api=<tweepy.api.API object at 0x10e81d2d0>, verified=False, blocked_by=False, profile_text_color=u'333333', muting=False, profile_image_url_https=u'https://pbs.twimg.com/profile_images/1029623502121381889/ODs6sQfB_normal.jpg', _json={u'follow_request_sent': False, u'has_extended_profile': False, u'profile_use_background_image': True, u'live_following': False, u'default_profile_image': False, u'id': 1029621764719083520, u'profile_background_image_url_https': None, u'translator_type': u'none', u'verified': False, u'blocked_by': False, u'profile_text_color': u'333333', u'muting': False, u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1029623502121381889/ODs6sQfB_normal.jpg', u'profile_sidebar_fill_color': u'DDEEF6', u'entities': {u'description': {u'urls': [{u'url': u'https://t.co/yVtFx9XoeD', u'indices': [0, 23], u'expanded_url': u'http://Answiz.com', u'display_url': u'Answiz.com'}]}}, u'followers_count': 55, u'profile_sidebar_border_color': u'C0DEED', u'id_str': u'1029621764719083520', u'profile_background_color': u'F5F8FA', u'listed_count': 0, u'status': {u'contributors': None, u'truncated': False, u'text': u'solve your problems related to react.js by answiz \nhttps://t.co/Oo7ey9g46k\n#react #js #answiz', u'is_quote_status': False, u'in_reply_to_status_id': None, u'id': 1046772358852345856, u'favorite_count': 0, u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', u'retweeted': False, u'coordinates': None, u'entities': {u'symbols': [], u'user_mentions': [], u'hashtags': [{u'indices': [75, 81], u'text': u'react'}, {u'indices': [82, 85], u'text': u'js'}, {u'indices': [86, 93], u'text': u'answiz'}], u'urls': [{u'url': u'https://t.co/Oo7ey9g46k', u'indices': [51, 74], u'expanded_url': u'https://www.answiz.com/categories/language/reactjs', u'display_url': u'answiz.com/categories/lan\u2026'}]}, u'in_reply_to_screen_name': None, u'in_reply_to_user_id': None, u'retweet_count': 0, u'id_str': u'1046772358852345856', u'favorited': False, u'geo': None, u'in_reply_to_user_id_str': None, u'possibly_sensitive': False, u'lang': u'en', u'created_at': u'Mon Oct 01 14:42:33 +0000 2018', u'in_reply_to_status_id_str': None, u'place': None}, u'is_translation_enabled': False, u'utc_offset': None, u'statuses_count': 7, u'description': u'https://t.co/yVtFx9XoeD is the largest online community for programmers to learn, share their knowledge and build their careers.', u'friends_count': 802, u'location': u'Gujrat Pakistan', u'profile_link_color': u'1DA1F2', u'profile_image_url': u'http://pbs.twimg.com/profile_images/1029623502121381889/ODs6sQfB_normal.jpg', u'following': False, u'geo_enabled': False, u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/1029621764719083520/1534316328', u'blocking': False, u'profile_background_image_url': None, u'screen_name': u'ANSWIZ1', u'lang': None, u'profile_background_tile': False, u'favourites_count': 1, u'name': u'ANSWIZ', u'notifications': False, u'url': None, u'created_at': u'Wed Aug 15 06:52:12 +0000 2018', u'contributors_enabled': False, u'time_zone': None, u'protected': False, u'default_profile': True, u'is_translator': False}, is_translator=False, geo_enabled=False, entities={u'description': {u'urls': [{u'url': u'https://t.co/yVtFx9XoeD', u'indices': [0, 23], u'expanded_url': u'http://Answiz.com', u'display_url': u'Answiz.com'}]}}, followers_count=55, protected=False, id_str=u'1029621764719083520', default_profile_image=False, listed_count=0, status=Status(contributors=None, truncated=False, text=u'solve your problems related to react.js by answiz \nhttps://t.co/Oo7ey9g46k\n#react #js #answiz', is_quote_status=False, i ...

# %%
print("Loading people I follow into a list")
friends = []
for friend in limit_handler(tweepy.Cursor(api.friends).items()):
    friends.append(friend)
# Out:
# Loading people I follow into a list

# %%
print "Adding followers relationships..."
for user in followers:
	graph.add_edge(user.name,"arnav")
# Out:
# Adding followers relationships...

# %%
print "Adding following relationships..."
for user in friends:
	graph.add_edge("arnav",user.name)
# Out:
# Adding following relationships...

# %%
len(followers)

# %%
nx.draw(graph)

# %%
plt.savefig("path.png")

# %%
len(graph)
# Out:
# 101

# %%
nx.draw(graph, with_labels=True, font_weight='bold')
